# %%
import os
import csv
from tqdm import tqdm
from scipy.io import wavfile
import numpy as np
import librosa
from sklearn.preprocessing import MinMaxScaler
import pickle
import tensorflow as tf
import keras.backend as K

wav_dir = '/home/mabikana/Desktop/wav/2021/cleaned_wav/'
pickle_valence_file = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/valence.pickle'
pickle_arousal_file = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/arousal.pickle'
pickle_spectrogram_scaler_file = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/melspectrograms_scaler.pickle'
pickle_arousal_scaler_file = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/arousal_scaler.pickle'
pickle_valence_scaler_file = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/valence_scaler.pickle'
model_dir = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/model.h5'
test_dir = '/home/mabikana/Documents/PhD/SER Code/RECOLA Processing/test'

speech_rate = 44100
dur = 4
dur_multiplier = 25

# %%
# create and save spectrograms
def get_log_mel_spectrogram(path, n_fft, hop_length, n_mels):
    audio, sr = librosa.load(path, sr=8000, duration=dur)
    y = librosa.resample(audio, orig_sr=8000, target_sr=speech_rate)
    audio_len = speech_rate * dur
    
    file_length = np.size(y)
    if file_length != audio_len:
        y = np.concatenate((y, np.zeros(audio_len-file_length)), axis=0)
    
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)
    log_mel_spectrogram = log_mel_spectrogram.reshape(-1,1)

    return log_mel_spectrogram


# Concordance correlation coefficient (CCC)-based loss function - using non-inductive statistics
def ccc(gold, pred):
    gold       = K.squeeze(gold, axis=-1)
    pred       = K.squeeze(pred, axis=-1)
    gold_mean  = K.mean(gold, axis=-1, keepdims=True)
    pred_mean  = K.mean(pred, axis=-1, keepdims=True)
    covariance = (gold-gold_mean)*(pred-pred_mean)
    gold_var   = K.mean(K.square(gold-gold_mean), axis=-1,  keepdims=True)
    pred_var   = K.mean(K.square(pred-pred_mean), axis=-1, keepdims=True)
    ccc        = K.constant(2.) * covariance / (gold_var + pred_var + K.square(gold_mean - pred_mean) + K.epsilon())
    return ccc


def ccc_loss(gold, pred):  
    # input (num_batches, seq_len, 1)
    ccc_loss   = K.constant(1.) - ccc(gold, pred)

    return ccc_loss


def load_from_pickled_file(file_name):
    with open(file_name, 'rb') as handle:
        file = pickle.load(handle)
    return file

# %%
# load model
model = tf.keras.models.load_model(model_dir, custom_objects={"ccc_loss": ccc_loss, "ccc": ccc})

# load scalers
melspect_scaler = load_from_pickled_file(pickle_spectrogram_scaler_file)
valence_scaler = load_from_pickled_file(pickle_valence_scaler_file)
arousal_scaler = load_from_pickled_file(pickle_arousal_scaler_file)

# %%
chunk_length_ms = dur * 1000
slice_length = int(chunk_length_ms / 1000) # in seconds
overlap =  int((chunk_length_ms / 1000) / 2) # in seconds

for wav_file in os.listdir(wav_dir):
    frequency, signal = wavfile.read(wav_dir + wav_file)
    slices = np.arange(0, len(signal)/frequency, slice_length-overlap, dtype=int)
    i = 0
    chunk_counter = 0

    valence = []
    arousal = []

    for start, end in zip(slices[:-1], slices[1:]):
        start_audio = start * frequency
        end_audio = (end + overlap)* frequency
        audio_slice = signal[int(start_audio): int(end_audio)]
        chunk_name = test_dir + '/test_{0}.wav'.format(chunk_counter)
        wavfile.write(chunk_name, 8000, audio_slice)
        spect = get_log_mel_spectrogram(path=chunk_name, n_fft=2048, hop_length=512, n_mels=128)
        spect = spect.reshape(1,-1)
        normalized_audio_slice = melspect_scaler.transform(spect)
        input_mel = np.reshape(normalized_audio_slice,(1,128, -1,1))
        predictions = model.predict(input_mel)

    #     print("Predictions ", predictions)
        valence.append(valence_scaler.inverse_transform(predictions[0]))
        arousal.append(arousal_scaler.inverse_transform(predictions[1]))
        chunk_counter += 1

    # print("\n")
    # print("Valence ", [x[0][0] for x in valence])
    # print("\n")
    # print("Arousal ", [x[0][0] for x in arousal])
# Out:
# Predictions  [array([[-0.158096]], dtype=float32), array([[-0.00997522]], dtype=float32)]
# Predictions  [array([[-0.29140925]], dtype=float32), array([[0.07460787]], dtype=float32)]
# Predictions  [array([[-0.16084649]], dtype=float32), array([[0.29166558]], dtype=float32)]
# Predictions  [array([[-0.429802]], dtype=float32), array([[0.11677528]], dtype=float32)]
# Predictions  [array([[0.03683661]], dtype=float32), array([[0.17612834]], dtype=float32)]
# Predictions  [array([[0.07435983]], dtype=float32), array([[0.23790424]], dtype=float32)]
# Predictions  [array([[0.08525831]], dtype=float32), array([[0.20854019]], dtype=float32)]
# Predictions  [array([[-0.06891292]], dtype=float32), array([[0.26207522]], dtype=float32)]
# Predictions  [array([[-0.41961613]], dtype=float32), array([[0.20721011]], dtype=float32)]
# Predictions  [array([[-0.39948097]], dtype=float32), array([[0.12804277]], dtype=float32)]
# Predictions  [array([[-0.08424418]], dtype=float32), array([[0.22141093]], dtype=float32)]
# Predictions  [array([[-0.26475874]], dtype=float32), array([[0.29435182]], dtype=float32)]
# Predictions  [array([[-0.32686633]], dtype=float32), array([[0.16626458]], dtype=float32)]
# Predictions  [array([[0.09366938]], dtype=float32), array([[0.31082517]], dtype=float32)]
# Predictions  [array([[-0.13504438]], dtype=float32), array([[0.22078471]], dtype=float32)]
# Predictions  [array([[-0.10478411]], dtype=float32), array([[0.26576808]], dtype=float32)]
# Predictions  [array([[-0.18408945]], dtype=float32), array([[0.20139097]], dtype=float32)]
# Predictions  [array([[-0.37894216]], dtype=float32), array([[0.15864645]], dtype=float32)]
# Predictions  [array([[-0.32508698]], dtype=float32), array([[0.16716059]], dtype=float32)]
# Predictions  [array([[-0.3483109]], dtype=float32), array([[0.07147945]], dtype=float32)]
# Predictions  [array([[-0.18368481]], dtype=float32), array([[0.3552658]], dtype=float32)]
# Predictions  [array([[-0.01110113]], dtype=float32), array([[0.27695522]], dtype=float32)]
# Predictions  [array([[-0.10799161]], dtype=float32), array([[0.1922677]], dtype=float32)]
# Predictions  [array([[-0.49976146]], dtype=float32), array([[0.09037491]], dtype=float32)]
# Predictions  [array([[-0.4598597]], dtype=float32), array([[0.1410655]], dtype=float32)]
# Predictions  [array([[-0.24978448]], dtype=float32), array([[0.11566821]], dtype=float32)]
# Predictions  [array([[-0.2407935]], dtype=float32), array([[0.13503473]], dtype=float32)]
# Predictions  [array([[-0.15929003]], dtype=float32), array([[0.09845006]], dtype=float32)]
# Predictions  [array([[-0.17966244]], dtype=float32), array([[0.14660615]], dtype=float32)]
# Predictions  [array([[-0.3457041]], dtype=float32), array([[0.11642998]], dtype=float32)]
# Predictions  [array([[-0.31874985]], dtype=float32), array([[0.12586321]], dtype=float32)]
# Predictions  [array([[-0.4222007]], dtype=float32), array([[0.13950735]], dtype=float32)]
# Predictions  [array([[-0.5842936]], dtype=float32), array([[0.15837874]], dtype=float32)]
# Predictions  [array([[0.00644507]], dtype=float32), array([[0.2030976]], dtype=float32)]
# Predictions  [array([[0.03134541]], dtype=float32), array([[0.3565631]], dtype=float32)]
# Predictions  [array([[-0.30386347]], dtype=float32), array([[0.2716]], dtype=float32)]
# Predictions  [array([[-0.49490237]], dtype=float32), array([[0.11620267]], dtype=float32)]
# Predictions  [array([[-0.3985098]], dtype=float32), array([[0.14394863]], dtype=float32)]
# Predictions  [array([[-0.12122036]], dtype=float32), array([[0.23073094]], dtype=float32)]
# Predictions  [array([[-0.18654226]], dtype=float32), array([[0.22372554]], dtype=float32)]
# Predictions  [array([[0.13953297]], dtype=float32), array([[0.21030818]], dtype=float32)]
# Predictions  [array([[0.07207955]], dtype=float32), array([[0.26556802]], dtype=float32)]
# Predictions  [array([[-0.27063605]], dtype=float32), array([[0.26509008]], dtype=float32)]
# Predictions  [array([[-0.32344332]], dtype=float32), array([[0.2516096]], dtype=float32)]
# Predictions  [array([[-0.07098629]], dtype=float32), array([[0.27444458]], dtype=float32)]
# Predictions  [array([[-0.28541365]], dtype=float32), array([[0.16045998]], dtype=float32)]
# Predictions  [array([[-0.32467178]], dtype=float32), array([[0.24766462]], dtype=float32)]
# Predictions  [array([[-0.52468264]], dtype=float32), array([[0.2632904]], dtype=float32)]
# Predictions  [array([[-0.18069044]], dtype=float32), array([[0.33138266]], dtype=float32)]
# Predictions  [array([[-0.07141]], dtype=float32), array([[0.35109222]], dtype=float32)]
# Predictions  [array([[-0.3856592]], dtype=float32), array([[0.17334042]], dtype=float32)]
# Predictions  [array([[-0.37161854]], dtype=float32), array([[0.12363772]], dtype=float32)]
# Predictions  [array([[0.04324993]], dtype=float32), array([[0.24038908]], dtype=float32)]
# Predictions  [array([[-0.04231494]], dtype=float32), array([[0.16582416]], dtype=float32)]
# Predictions  [array([[-0.38911307]], dtype=float32), array([[0.16764654]], dtype=float32)]
# Predictions  [array([[-0.4455261]], dtype=float32), array([[0.12575705]], dtype=float32)]
# Predictions  [array([[-0.5986502]], dtype=float32), array([[0.05895528]], dtype=float32)]
# Predictions  [array([[-0.4993131]], dtype=float32), array([[0.11614903]], dtype=float32)]
# Predictions  [array([[-0.6198984]], dtype=float32), array([[0.07339027]], dtype=float32)]
# Predictions  [array([[-0.23824175]], dtype=float32), array([[0.2702683]], dtype=float32)]
# Predictions  [array([[-0.10993074]], dtype=float32), array([[0.21090531]], dtype=float32)]
# Predictions  [array([[0.10208873]], dtype=float32), array([[0.2782407]], dtype=float32)]
# Predictions  [array([[-0.03647762]], dtype=float32), array([[0.35116327]], dtype=float32)]
# Predictions  [array([[-0.29865086]], dtype=float32), array([[0.2469542]], dtype=float32)]
# Predictions  [array([[-0.56346923]], dtype=float32), array([[0.02967458]], dtype=float32)]
# Predictions  [array([[-0.12768272]], dtype=float32), array([[0.07338669]], dtype=float32)]
# Predictions  [array([[-0.31957686]], dtype=float32), array([[-0.03919195]], dtype=float32)]
# Predictions  [array([[-0.3380348]], dtype=float32), array([[-0.15113904]], dtype=float32)]
# Predictions  [array([[-0.0780939]], dtype=float32), array([[-0.16172843]], dtype=float32)]
# Predictions  [array([[-0.27680305]], dtype=float32), array([[-0.00737739]], dtype=float32)]
# Predictions  [array([[0.03178555]], dtype=float32), array([[0.01629822]], dtype=float32)]
# Predictions  [array([[-0.26384646]], dtype=float32), array([[0.10491315]], dtype=float32)]
# Predictions  [array([[-0.42179132]], dtype=float32), array([[0.01250169]], dtype=float32)]
# Predictions  [array([[-0.06608246]], dtype=float32), array([[0.05916816]], dtype=float32)]
# Predictions  [array([[-0.1660449]], dtype=float32), array([[0.1366449]], dtype=float32)]
# Predictions  [array([[-0.17440915]], dtype=float32), array([[0.21529342]], dtype=float32)]
# Predictions  [array([[0.12954411]], dtype=float32), array([[0.14213262]], dtype=float32)]
# Predictions  [array([[-0.19072588]], dtype=float32), array([[0.14711173]], dtype=float32)]
# Predictions  [array([[-0.02271258]], dtype=float32), array([[0.147081]], dtype=float32)]
# Predictions  [array([[0.2394345]], dtype=float32), array([[0.13127744]], dtype=float32)]
# Predictions  [array([[0.01289909]], dtype=float32), array([[0.1307718]], dtype=float32)]
# Predictions  [array([[-0.27356032]], dtype=float32), array([[0.11403718]], dtype=float32)]
# Predictions  [array([[-0.05134343]], dtype=float32), array([[-0.00481259]], dtype=float32)]
# Predictions  [array([[-0.15560071]], dtype=float32), array([[-0.05388586]], dtype=float32)]
# Predictions  [array([[0.15159653]], dtype=float32), array([[0.07077523]], dtype=float32)]
# Predictions  [array([[-0.16950877]], dtype=float32), array([[-0.02849668]], dtype=float32)]
# Predictions  [array([[0.08511265]], dtype=float32), array([[0.14772215]], dtype=float32)]
# Predictions  [array([[0.00014329]], dtype=float32), array([[-0.1700479]], dtype=float32)]
